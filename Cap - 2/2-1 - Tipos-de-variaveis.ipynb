# %%
import pandas as pd

# %%
tab21 = pd.read_excel('/kaggle/input/db-morettin/Dados_EB.xls', sheet_name='Tabela 2.1', skiprows=1)

# %%
tab21.columns
# Out:
# Index(['N', 'Estado Civil', 'Grau de Instrução', 'N de Filhos',
#        'Salario (x Sal Min)', 'Anos', 'Meses', 'Região de Procedência'],
#       dtype='object')
